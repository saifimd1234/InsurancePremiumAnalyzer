# %%
import os
import glob
import pandas as pd
import pdfplumber
import re
from IPython.display import display

# --- 1. SETUP: Define your data and output directories ---
BASE_DIR = os.getcwd() 
DATA_DIR = os.path.join(BASE_DIR, "data")
OUT_DIR = os.path.join(BASE_DIR, "output")

# Create directories if they don't exist
os.makedirs(DATA_DIR, exist_ok=True)
os.makedirs(OUT_DIR, exist_ok=True)

print(f"Data will be read from: {DATA_DIR}")
print(f"Output will be saved to: {OUT_DIR}")
# Out:
# Data will be read from: c:\Users\saifi\GitHub\InsurancePremiumAnalyzer\data\SBI GENERAL INSURANCE\data
# Output will be saved to: c:\Users\saifi\GitHub\InsurancePremiumAnalyzer\data\SBI GENERAL INSURANCE\output

# %%
# --- Helper function for cleaning numeric values ---
def clean_value(text):
    """Cleans a string to extract a numeric value, returning 0 on failure."""
    if text is None:
        return 0
    cleaned_text = re.sub(r'[^\d.-]', '', str(text))
    if not cleaned_text or cleaned_text == '-':
        return 0
    try:
        return int(float(cleaned_text))
    except (ValueError, TypeError):
        return 0

# --- THE NEW UNIVERSAL PARSER ---
def parse_universal_nl4(pdf_path):
    """
    Extracts data from FORM NL-4 by trying multiple strategies.
    It first attempts a simple header extraction, and if that fails,
    it tries a more complex multi-level header extraction.
    
    The `laparams` argument is added to pdfplumber.open to improve
    text layout analysis for complex PDFs, which can help avoid the
    issues hinted at by the "Cannot set gray" warnings.
    """
    provider = "Unknown"
    month_map = {'june': 'Q1', 'september': 'Q2', 'december': 'Q3', 'march': 'Q4'}
    
    try:
        # Added laparams to help with layout analysis on complex PDFs
        with pdfplumber.open(pdf_path, laparams={"line_margin": 0.5, "char_margin": 2.0}) as pdf:
            for page in pdf.pages:
                page_text = page.extract_text(x_tolerance=2, layout=True) or ""
                if "FORM NL-4" not in page_text or "PREMIUM SCHEDULE" not in page_text:
                    continue

                # --- STEP 1: Extract Provider Name ---
                provider_match = re.search(r"Name\s+of\s+(?:the\s+)?Insurer\s*[:\s]+\s*(.+)", page_text, re.IGNORECASE)
                if provider_match:
                    provider = provider_match.group(1).strip()
                else: # Fallback for other formats
                    for line in page_text.splitlines()[:5]:
                        if "Insurance" in line and ("Ltd" in line or "Limited" in line):
                            provider = line.strip()
                            break

                # --- STEP 2: Extract Year and Quarter (Flexible Regex) ---
                year, quarter = None, None
                # Regex to find "For the Quarter September, 2024" OR "For the quarter ended 30th June 2024"
                date_match = re.search(r"For\s+the\s+Quarter\s+(?:Ended\s*)?(?:on\s|at\s)?(?:the\s)?\d{0,2}\w{0,2}\s*([A-Za-z]+)[, ]+\s*(\d{4})", page_text, re.IGNORECASE)
                if date_match:
                    month_str, year_str = date_match.group(1).lower(), date_match.group(2)
                    year = int(year_str)
                    quarter = month_map.get(month_str[:3])
                
                if not year or not quarter: continue

                # --- STEP 3: Extract Table ---
                table = page.extract_table({
                    "vertical_strategy": "lines", "horizontal_strategy": "text",
                    "text_x_tolerance": 2, "text_y_tolerance": 2,
                })
                if not table: continue

                # --- STRATEGY 1: Simple, Single-Row Header (like Aditya Birla) ---
                header_indices = {}
                for r in reversed(table):
                    row_str = " ".join(filter(None, [str(s).replace('\n', ' ') for s in r]))
                    if "Personal Accident" in row_str and "Travel" in row_str and "Health" in row_str:
                        for i, cell in enumerate(r):
                            if cell:
                                clean_cell = cell.replace('\n', ' ').strip()
                                if clean_cell == "Health": header_indices['health'] = i
                                elif clean_cell == "Personal Accident": header_indices['personal_accident'] = i
                                elif clean_cell == "Travel Insurance": header_indices['travel'] = i
                        if 'health' in header_indices and 'personal_accident' in header_indices:
                            break
                
                # If simple strategy works, find data and return
                if 'health' in header_indices:
                    for r in table:
                        if r and any(cell and "Gross Direct Premium" in str(cell) for cell in r):
                            return {
                                "provider": provider, "year": year, "quarter": quarter,
                                "health": clean_value(r[header_indices.get('health')]),
                                "personal_accident": clean_value(r[header_indices.get('personal_accident')]),
                                "travel": clean_value(r[header_indices.get('travel')]),
                                "total": clean_value(r[header_indices.get('total')]) or (clean_value(r[header_indices.get('health')]) + clean_value(r[header_indices.get('personal_accident')]) + clean_value(r[header_indices.get('travel')])),
                                "source_file": os.path.basename(pdf_path)
                            }
                
                # --- STRATEGY 2: Multi-Level Header (like SBI) ---
                h1_idx, h2_idx = None, None
                for i, row in enumerate(table):
                    row_str = " ".join(filter(None, [str(c).replace('\n', ' ') for c in row]))
                    if "Personal Accident" in row_str and "Health Insurance" in row_str:
                        if i + 1 < len(table):
                            next_row_str = " ".join(filter(None, [str(c).replace('\n', ' ') for c in table[i+1]]))
                            if "For the quarter" in next_row_str:
                                h1_idx, h2_idx = i, i + 1
                                break
                
                if h1_idx is not None:
                    header_map = {}
                    current_primary = ""
                    for j, cell in enumerate(table[h1_idx]):
                        if cell and cell.strip(): current_primary = cell.replace('\n', ' ').strip()
                        s_header = table[h2_idx][j].replace('\n', ' ').strip() if table[h2_idx][j] else ""
                        header_map[j] = (current_primary, s_header)
                    
                    col_indices = {}
                    for idx, (p_header, s_header) in header_map.items():
                        if "For the quarter" in s_header and str(year) in s_header:
                            if "Health" in p_header: col_indices['health'] = idx
                            elif "Personal Accident" in p_header: col_indices['personal_accident'] = idx
                            elif "Travel" in p_header: col_indices['travel'] = idx
                    
                    if 'health' in col_indices:
                        for r in table:
                             if r and any(cell and "Gross Direct Premium" in str(cell) for cell in r):
                                h_val = clean_value(r[col_indices.get('health')])
                                pa_val = clean_value(r[col_indices.get('personal_accident')])
                                t_val = clean_value(r[col_indices.get('travel')])
                                return {
                                    "provider": provider, "year": year, "quarter": quarter,
                                    "health": h_val, "personal_accident": pa_val, "travel": t_val,
                                    "total": h_val + pa_val + t_val,
                                    "source_file": os.path.basename(pdf_path)
                                }
                break # Processed the correct page, move to next PDF
    except Exception as e:
        print(f"  -> An error occurred while processing {os.path.basename(pdf_path)}: {e}")
    
    return None # Return None if all strategies fail

# %%
# --- 3. PROCESSING LOOP: Extract data from all PDFs ---
records = []
failed_files = []

pdf_files = sorted(glob.glob(os.path.join(DATA_DIR, "*.pdf")))

if not pdf_files:
    print(f"❌ No PDF files found in '{DATA_DIR}'.")
    print("Please make sure your PDF files are in the 'data' folder.")
else:
    for pdf_file in pdf_files:
        print(f"📄 Processing: {os.path.basename(pdf_file)}")
        # Use the NEW universal parsing function
        result = parse_universal_nl4(pdf_file)
        if result:
            print(f"✅ Extracted: {result['provider']}, {result['year']} {result['quarter']}")
            records.append(result)
        else:
            print(f"❌ Failed to extract data from: {os.path.basename(pdf_file)}")
            failed_files.append(os.path.basename(pdf_file))

    print(f"\nTotal successfully extracted: {len(records)}")
    if failed_files:
        print(f"Total failed: {len(failed_files)}")
        print("Failed files:", failed_files)
# Out:
# 📄 Processing: Q1 2024.pdf
# Cannot set gray non-stroke color because /'P54' is an invalid float value
# Cannot set gray non-stroke color because /'P56' is an invalid float value
# Cannot set gray non-stroke color because /'P57' is an invalid float value
# Cannot set gray non-stroke color because /'P59' is an invalid float value
# Cannot set gray non-stroke color because /'P61' is an invalid float value
# Cannot set gray non-stroke color because /'P62' is an invalid float value
# Cannot set gray non-stroke color because /'P63' is an invalid float value
# Cannot set gray non-stroke color because /'P64' is an invalid float value
# Cannot set gray non-stroke color because /'P65' is an invalid float value
# Cannot set gray non-stroke color because /'P66' is an invalid float value
# Cannot set gray non-stroke color because /'P68' is an invalid float value
# Cannot set gray non-stroke color because /'P69' is an invalid float value
# Cannot set gray non-stroke color because /'P70' is an invalid float value
# Cannot set gray non-stroke color because /'P71' is an invalid float value
# Cannot set gray non-stroke color because /'P72' is an invalid float value
# Cannot set gray non-stroke color because /'P74' is an invalid float value
# Cannot set gray non-stroke color because /'P75' is an invalid float value
# Cannot set gray non-stroke color because /'P76' is an invalid float value
# Cannot set gray non-stroke color because /'P77' is an invalid float value
# Cannot set gray non-stroke color because /'P78' is an invalid float value
# Cannot set gray non-stroke color because /'P79' is an invalid float value
# Cannot set gray non-stroke color because /'P80' is an invalid float value
# Cannot set gray non-stroke color because /'P81' is an invalid float value
# Cannot set gray non-stroke color because /'P82' is an invalid float value
# Cannot set gray non-stroke color because /'P83' is an invalid float value
# Cannot set gray non-stroke color because /'P85' is an invalid float value
# Cannot set gray non-stroke color because /'P86' is an invalid float value
# Cannot set gray non-stroke color because /'P87' is an invalid float value
# Cannot set gray non-stroke color because /'P88' is an invalid float value
# Cannot set gray non-stroke color because /'P89' is an invalid float value
# Cannot set gray non-stroke color because /'P90' is an invalid float value
# Cannot set gray non-stroke color because /'P91' is an invalid float value
# Cannot set gray non-stroke color because /'P18' is an invalid float value
# Cannot set gray non-stroke color because /'P20' is an invalid float value
# Cannot set gray non-stroke color because /'P22' is an invalid float value
# Cannot set gray non-stroke color because /'P24' is an invalid float value
# Cannot set gray non-stroke color because /'P25' is an invalid float value
# Cannot set gray non-stroke color because /'P26' is an invalid float value
# Cannot set gray non-stroke color because /'P28' is an invalid float value
# Cannot set gray non-stroke color because /'P30' is an invalid float value
# Cannot set gray non-stroke color because /'P32' is an invalid float value
# Cannot set gray non-stroke color because /'P34' is an invalid float value
# Cannot set gray non-stroke color because /'P36' is an invalid float value
# Cannot set gray non-stroke color because /'P38' is an invalid float value
# Cannot set gray non-stroke color because /'P40' is an invalid float value
# Cannot set gray non-stroke color because /'P41' is an invalid float value
# Cannot set gray non-stroke color because /'P43' is an invalid float value
# Cannot set gray non-stroke color because /'P45' is an invalid float value
# Cannot set gray non-stroke color because /'P46' is an invalid float value
# Cannot set gray non-stroke color because /'P48' is an invalid float value
# Cannot set gray non-stroke color because /'P49' is an invalid float value
# Cannot set gray non-stroke color because /'P50' is an invalid float value
# Cannot set gray non-stroke color because /'P51' is an invalid float value
# Cannot set gray non-stroke color because /'P53' is an invalid float value
# Cannot set gray non-stroke color because /'P54' is an invalid float value
# Cannot set gray non-stroke color because /'P56' is an invalid float value
# Cannot set gray non-stroke color because /'P58' is an invalid float value
# Cannot set gray non-stroke color because /'P60' is an invalid float value
# Cannot set gray non-stroke color because /'P61' is an invalid float value
# Cannot set gray non-stroke color because /'P62' is an invalid float value
# Cannot set gray non-stroke color because /'P63' is an invalid float value
# Cannot set gray non-stroke color because /'P64' is an invalid float value
# Cannot set gray non-stroke color because /'P65' is an invalid float value
# Cannot set gray non-stroke color because /'P66' is an invalid float value
# Cannot set gray non-stroke color because /'P67' is an invalid float value
# Cannot set gray non-stroke color because /'P68' is an invalid float value
# Cannot set gray non-stroke color because /'P69' is an invalid float value
# Cannot set gray non-stroke color because /'P70' is an invalid float value
# Cannot set gray non-stroke color because /'P71' is an invalid float value
# Cannot set gray non-stroke color because /'P72' is an invalid float value
# Cannot set gray non-stroke color because /'P74' is an invalid float value
# Cannot set gray non-stroke color because /'P76' is an invalid float value
# Cannot set gray non-stroke color because /'P77' is an invalid float value
# Cannot set gray non-stroke color because /'P78' is an invalid float value
# Cannot set gray non-stroke color because /'P80' is an invalid float value
# Cannot set gray non-stroke color because /'P81' is an invalid float value
# Cannot set gray non-stroke color because /'P82' is an invalid float value
# Cannot set gray non-stroke color because /'P83' is an invalid float value
# Cannot set gray non-stroke color because /'P85' is an invalid float value
# Cannot set gray non-stroke color because /'P86' is an invalid float value
# Cannot set gray non-stroke color because /'P87' is an invalid float value
# Cannot set gray non-stroke color because /'P88' is an invalid float value
# Cannot set gray non-stroke color because /'P89' is an invalid float value
# Cannot set gray non-stroke color because /'P90' is an invalid float value
# Cannot set gray non-stroke color because /'P91' is an invalid float value
# Cannot set gray non-stroke color because /'P93' is an invalid float value
# Cannot set gray non-stroke color because /'P94' is an invalid float value
# Cannot set gray non-stroke color because /'P95' is an invalid float value
# Cannot set gray non-stroke color because /'P97' is an invalid float value
# Cannot set gray non-stroke color because /'P98' is an invalid float value
# Cannot set gray non-stroke color because /'P99' is an invalid float value
# Cannot set gray non-stroke color because /'P100' is an invalid float value
# Cannot set gray non-stroke color because /'P101' is an invalid float value
# Cannot set gray non-stroke color because /'P102' is an invalid float value
# Cannot set gray non-stroke color because /'P103' is an invalid float value
# Cannot set gray non-stroke color because /'P104' is an invalid float value
# Cannot set gray non-stroke color because /'P105' is an invalid float value
# Cannot set gray non-stroke color because /'P106' is an invalid float value
# Cannot set gray non-stroke color because /'P107' is an invalid float value
# Cannot set gray non-stroke color because /'P108' is an invalid float value
# Cannot set gray non-stroke color because /'P109' is an invalid float value
# Cannot set gray non-stroke color because /'P110' is an invalid float value
# Cannot set gray non-stroke color because /'P111' is an invalid float value
# Cannot set gray non-stroke color because /'P112' is an invalid float value
# Cannot set gray non-stroke color because /'P113' is an invalid float value
# Cannot set gray non-stroke color because /'P114' is an invalid float value
# Cannot set gray non-stroke color because /'P115' is an invalid float value
# Cannot set gray non-stroke color because /'P116' is an invalid float value
# Cannot set gray non-stroke color because /'P117' is an invalid float value
# Cannot set gray non-stroke color because /'P118' is an invalid float value
# Cannot set gray non-stroke color because /'P119' is an invalid float value
# Cannot set gray non-stroke color because /'P120' is an invalid float value
# Cannot set gray non-stroke color because /'P121' is an invalid float value
# Cannot set gray non-stroke color because /'P122' is an invalid float value
# Cannot set gray non-stroke color because /'P123' is an invalid float value
# Cannot set gray non-stroke color because /'P124' is an invalid float value
# Cannot set gray non-stroke color because /'P125' is an invalid float value
# Cannot set gray non-stroke color because /'P126' is an invalid float value
# Cannot set gray non-stroke color because /'P127' is an invalid float value
# Cannot set gray non-stroke color because /'P128' is an invalid float value
# Cannot set gray non-stroke color because /'P129' is an invalid float value
# Cannot set gray non-stroke color because /'P130' is an invalid float value
# Cannot set gray non-stroke color because /'P131' is an invalid float value
# Cannot set gray non-stroke color because /'P132' is an invalid float value
# Cannot set gray non-stroke color because /'P133' is an invalid float value
# Cannot set gray non-stroke color because /'P134' is an invalid float value
# Cannot set gray non-stroke color because /'P135' is an invalid float value
# Cannot set gray non-stroke color because /'P136' is an invalid float value
# Cannot set gray non-stroke color because /'P137' is an invalid float value
# Cannot set gray non-stroke color because /'P138' is an invalid float value
# Cannot set gray non-stroke color because /'P139' is an invalid float value
# Cannot set gray non-stroke color because /'P140' is an invalid float value
# Cannot set gray non-stroke color because /'P141' is an invalid float value
# Cannot set gray non-stroke color because /'P142' is an invalid float value
# Cannot set gray non-stroke color because /'P143' is an invalid float value
# Cannot set gray non-stroke color because /'P144' is an invalid float value
# Cannot set gray non-stroke color because /'P145' is an invalid float value
# Cannot set gray non-stroke color because /'P146' is an invalid float value
# Cannot set gray non-stroke color because /'P147' is an invalid float value
# Cannot set gray non-stroke color because /'P148' is an invalid float value
# Cannot set gray non-stroke color because /'P149' is an invalid float value
# Cannot set gray non-stroke color because /'P150' is an invalid float value
# Cannot set gray non-stroke color because /'P151' is an invalid float value
# Cannot set gray non-stroke color because /'P152' is an invalid float value
# Cannot set gray non-stroke color because /'P153' is an invalid float value
# Cannot set gray non-stroke color because /'P154' is an invalid float value
# Cannot set gray non-stroke color because /'P155' is an invalid float value
# Cannot set gray non-stroke color because /'P156' is an invalid float value
# Cannot set gray non-stroke color because /'P157' is an invalid float value
# Cannot set gray non-stroke color because /'P158' is an invalid float value
# Cannot set gray non-stroke color because /'P159' is an invalid float value
# Cannot set gray non-stroke color because /'P160' is an invalid float value
# Cannot set gray non-stroke color because /'P161' is an invalid float value
# Cannot set gray non-stroke color because /'P162' is an invalid float value
# Cannot set gray non-stroke color because /'P163' is an invalid float value
# Cannot set gray non-stroke color because /'P164' is an invalid float value
# Cannot set gray non-stroke color because /'P165' is an invalid float value
# Cannot set gray non-stroke color because /'P166' is an invalid float value
# Cannot set gray non-stroke color because /'P167' is an invalid float value
# Cannot set gray non-stroke color because /'P168' is an invalid float value
# Cannot set gray non-stroke color because /'P169' is an invalid float value
# Cannot set gray non-stroke color because /'P170' is an invalid float value
# Cannot set gray non-stroke color because /'P171' is an invalid float value
# Cannot set gray non-stroke color because /'P172' is an invalid float value
# Cannot set gray non-stroke color because /'P173' is an invalid float value
# Cannot set gray non-stroke color because /'P174' is an invalid float value
# Cannot set gray non-stroke color because /'P175' is an invalid float value
# Cannot set gray non-stroke color because /'P176' is an invalid float value
# Cannot set gray non-stroke color because /'P177' is an invalid float value
# Cannot set gray non-stroke color because /'P178' is an invalid float value
# Cannot set gray non-stroke color because /'P179' is an invalid float value
# Cannot set gray non-stroke color because /'P180' is an invalid float value
# Cannot set gray non-stroke color because /'P181' is an invalid float value
# Cannot set gray non-stroke color because /'P182' is an invalid float value
# Cannot set gray non-stroke color because /'P183' is an invalid float value
# Cannot set gray non-stroke color because /'P184' is an invalid float value
# Cannot set gray non-stroke color because /'P185' is an invalid float value
# Cannot set gray non-stroke color because /'P186' is an invalid float value
# Cannot set gray non-stroke color because /'P187' is an invalid float value
# Cannot set gray non-stroke color because /'P188' is an invalid float value
# Cannot set gray non-stroke color because /'P189' is an invalid float value
# Cannot set gray non-stroke color because /'P190' is an invalid float value
# Cannot set gray non-stroke color because /'P191' is an invalid float value
# Cannot set gray non-stroke color because /'P192' is an invalid float value
# Cannot set gray non-stroke color because /'P193' is an invalid float value
# Cannot set gray non-stroke color because /'P194' is an invalid float value
# Cannot set gray non-stroke color because /'P195' is an invalid float value
# Cannot set gray non-stroke color because /'P196' is an invalid float value
# Cannot set gray non-stroke color because /'P197' is an invalid float value
# Cannot set gray non-stroke color because /'P198' is an invalid float value
# Cannot set gray non-stroke color because /'P199' is an invalid float value
# Cannot set gray non-stroke color because /'P200' is an invalid float value
# Cannot set gray non-stroke color because /'P201' is an invalid float value
# Cannot set gray non-stroke color because /'P202' is an invalid float value
# Cannot set gray non-stroke color because /'P203' is an invalid float value
# Cannot set gray non-stroke color because /'P204' is an invalid float value
# Cannot set gray non-stroke color because /'P205' is an invalid float value
# Cannot set gray non-stroke color because /'P206' is an invalid float value
# Cannot set gray non-stroke color because /'P207' is an invalid float value
# Cannot set gray non-stroke color because /'P208' is an invalid float value
# Cannot set gray non-stroke color because /'P209' is an invalid float value
# Cannot set gray non-stroke color because /'P210' is an invalid float value
# Cannot set gray non-stroke color because /'P211' is an invalid float value
# Cannot set gray non-stroke color because /'P212' is an invalid float value
# Cannot set gray non-stroke color because /'P213' is an invalid float value
# Cannot set gray non-stroke color because /'P214' is an invalid float value
# Cannot set gray non-stroke color because /'P215' is an invalid float value
# Cannot set gray non-stroke color because /'P216' is an invalid float value
# Cannot set gray non-stroke color because /'P217' is an invalid float value
# Cannot set gray non-stroke color because /'P218' is an invalid float value
# Cannot set gray non-stroke color because /'P219' is an invalid float value
# Cannot set gray non-stroke color because /'P220' is an invalid float value
# Cannot set gray non-stroke color because /'P221' is an invalid float value
# Cannot set gray non-stroke color because /'P222' is an invalid float value
# Cannot set gray non-stroke color because /'P223' is an invalid float value
# Cannot set gray non-stroke color because /'P224' is an invalid float value
# Cannot set gray non-stroke color because /'P225' is an invalid float value
# Cannot set gray non-stroke color because /'P226' is an invalid float value
# Cannot set gray non-stroke color because /'P227' is an invalid float value
# Cannot set gray non-stroke color because /'P228' is an invalid float value
# Cannot set gray non-stroke color because /'P229' is an invalid float value
# Cannot set gray non-stroke color because /'P230' is an invalid float value
# Cannot set gray non-stroke color because /'P231' is an invalid float value
# Cannot set gray non-stroke color because /'P232' is an invalid float value
# Cannot set gray non-stroke color because /'P233' is an invalid float value
# Cannot set gray non-stroke color because /'P234' is an invalid float value
# Cannot set gray non-stroke color because /'P235' is an invalid float value
# Cannot set gray non-stroke color because /'P236' is an invalid float value
# Cannot set gray non-stroke color because /'P237' is an invalid float value
# Cannot set gray non-stroke color because /'P238' is an invalid float value
# Cannot set gray non-stroke color because /'P239' is an invalid float value
# Cannot set gray non-stroke color because /'P240' is an invalid float value
# Cannot set gray non-stroke color because /'P241' is an invalid float value
# Cannot set gray non-stroke color because /'P242' is an invalid float value
# Cannot set gray non-stroke color because /'P243' is an invalid float value
# Cannot set gray non-stroke color because /'P244' is an invalid float value
# Cannot set gray non-stroke color because /'P245' is an invalid float value
# Cannot set gray non-stroke color because /'P246' is an invalid float value
# Cannot set gray non-stroke color because /'P247' is an invalid float value
# Cannot set gray non-stroke color because /'P248' is an invalid float value
# Cannot set gray non-stroke color because /'P249' is an invalid float value
# Cannot set gray non-stroke color because /'P250' is an invalid float value
# Cannot set gray non-stroke color because /'P251' is an invalid float value
# Cannot set gray non-stroke color because /'P252' is an invalid float value
# Cannot set gray non-stroke color because /'P253' is an invalid float value
# Cannot set gray non-stroke color because /'P254' is an invalid float value
# Cannot set gray non-stroke color because /'P255' is an invalid float value
# Cannot set gray non-stroke color because /'P256' is an invalid float value
# Cannot set gray non-stroke color because /'P257' is an invalid float value
# Cannot set gray non-stroke color because /'P258' is an invalid float value
# Cannot set gray non-stroke color because /'P259' is an invalid float value
# Cannot set gray non-stroke color because /'P260' is an invalid float value
# Cannot set gray non-stroke color because /'P261' is an invalid float value
# Cannot set gray non-stroke color because /'P262' is an invalid float value
# Cannot set gray non-stroke color because /'P263' is an invalid float value
# Cannot set gray non-stroke color because /'P264' is an invalid float value
# Cannot set gray non-stroke color because /'P265' is an invalid float value
# Cannot set gray non-stroke color because /'P266' is an invalid float value
# Cannot set gray non-stroke color because /'P267' is an invalid float value
# Cannot set gray non-stroke color because /'P268' is an invalid float value
# Cannot set gray non-stroke color because /'P269' is an invalid float value
# Cannot set gray non-stroke color because /'P270' is an invalid float value
# Cannot set gray non-stroke color because /'P271' is an invalid float value
# Cannot set gray non-stroke color because /'P272' is an invalid float value
# Cannot set gray non-stroke color because /'P273' is an invalid float value
# Cannot set gray non-stroke color because /'P274' is an invalid float value
# Cannot set gray non-stroke color because /'P275' is an invalid float value
# Cannot set gray non-stroke color because /'P276' is an invalid float value
# Cannot set gray non-stroke color because /'P277' is an invalid float value
# Cannot set gray non-stroke color because /'P278' is an invalid float value
# Cannot set gray non-stroke color because /'P279' is an invalid float value
# Cannot set gray non-stroke color because /'P280' is an invalid float value
# Cannot set gray non-stroke color because /'P281' is an invalid float value
# Cannot set gray non-stroke color because /'P282' is an invalid float value
# Cannot set gray non-stroke color because /'P283' is an invalid float value
# Cannot set gray non-stroke color because /'P284' is an invalid float value
# Cannot set gray non-stroke color because /'P285' is an invalid float value
# Cannot set gray non-stroke color because /'P286' is an invalid float value
# Cannot set gray non-stroke color because /'P287' is an invalid float value
# Cannot set gray non-stroke color because /'P288' is an invalid float value
# Cannot set gray non-stroke color because /'P289' is an invalid float value
# Cannot set gray non-stroke color because /'P290' is an invalid float value
# Cannot set gray non-stroke color because /'P291' is an invalid float value
# Cannot set gray non-stroke color because /'P292' is an invalid float value
# Cannot set gray non-stroke color because /'P293' is an invalid float value
# Cannot set gray non-stroke color because /'P294' is an invalid float value
# Cannot set gray non-stroke color because /'P295' is an invalid float value
# Cannot set gray non-stroke color because /'P296' is an invalid float value
# Cannot set gray non-stroke color because /'P297' is an invalid float value
# Cannot set gray non-stroke color because /'P298' is an invalid float value
# Cannot set gray non-stroke color because /'P299' is an invalid float value
# Cannot set gray non-stroke color because /'P300' is an invalid float value
# Cannot set gray non-stroke color because /'P301' is an invalid float value
# Cannot set gray non-stroke color because /'P302' is an invalid float value
# Cannot set gray non-stroke color because /'P303' is an invalid float value
# Cannot set gray non-stroke color because /'P304' is an invalid float value
# Cannot set gray non-stroke color because /'P305' is an invalid float value
# Cannot set gray non-stroke color because /'P306' is an invalid float value
# Cannot set gray non-stroke color because /'P307' is an invalid float value
# Cannot set gray non-stroke color because /'P308' is an invalid float value
# Cannot set gray non-stroke color because /'P309' is an invalid float value
# Cannot set gray non-stroke color because /'P310' is an invalid float value
# Cannot set gray non-stroke color because /'P311' is an invalid float value
# Cannot set gray non-stroke color because /'P312' is an invalid float value
# Cannot set gray non-stroke color because /'P313' is an invalid float value
# Cannot set gray non-stroke color because /'P314' is an invalid float value
# Cannot set gray non-stroke color because /'P315' is an invalid float value
# Cannot set gray non-stroke color because /'P316' is an invalid float value
# Cannot set gray non-stroke color because /'P317' is an invalid float value
# Cannot set gray non-stroke color because /'P318' is an invalid float value
# Cannot set gray non-stroke color because /'P319' is an invalid float value
# Cannot set gray non-stroke color because /'P320' is an invalid float value
# Cannot set gray non-stroke color because /'P321' is an invalid float value
# Cannot set gray non-stroke color because /'P322' is an invalid float value
# Cannot set gray non-stroke color because /'P323' is an invalid float value
# Cannot set gray non-stroke color because /'P324' is an invalid float value
# Cannot set gray non-stroke color because /'P325' is an invalid float value
# Cannot set gray non-stroke color because /'P326' is an invalid float value
# Cannot set gray non-stroke color because /'P327' is an invalid float value
# Cannot set gray non-stroke color because /'P328' is an invalid float value
# Cannot set gray non-stroke color because /'P329' is an invalid float value
# Cannot set gray non-stroke color because /'P330' is an invalid float value
# Cannot set gray non-stroke color because /'P331' is an invalid float value
# Cannot set gray non-stroke color because /'P332' is an invalid float value
# Cannot set gray non-stroke color because /'P333' is an invalid float value
# Cannot set gray non-stroke color because /'P334' is an invalid float value
# Cannot set gray non-stroke color because /'P335' is an invalid float value
# Cannot set gray non-stroke color because /'P336' is an invalid float value
# Cannot set gray non-stroke color because /'P337' is an invalid float value
# Cannot set gray non-stroke color because /'P338' is an invalid float value
# Cannot set gray non-stroke color because /'P339' is an invalid float value
# Cannot set gray non-stroke color because /'P340' is an invalid float value
# Cannot set gray non-stroke color because /'P341' is an invalid float value
# Cannot set gray non-stroke color because /'P342' is an invalid float value
# Cannot set gray non-stroke color because /'P343' is an invalid float value
# Cannot set gray non-stroke color because /'P344' is an invalid float value
# Cannot set gray non-stroke color because /'P345' is an invalid float value
# Cannot set gray non-stroke color because /'P346' is an invalid float value
# Cannot set gray non-stroke color because /'P347' is an invalid float value
# Cannot set gray non-stroke color because /'P348' is an invalid float value
# Cannot set gray non-stroke color because /'P349' is an invalid float value
# Cannot set gray non-stroke color because /'P350' is an invalid float value
# Cannot set gray non-stroke color because /'P351' is an invalid float value
# Cannot set gray non-stroke color because /'P352' is an invalid float value
# Cannot set gray non-stroke color because /'P353' is an invalid float value
# Cannot set gray non-stroke color because /'P354' is an invalid float value
# Cannot set gray non-stroke color because /'P355' is an invalid float value
# Cannot set gray non-stroke color because /'P356' is an invalid float value
# Cannot set gray non-stroke color because /'P357' is an invalid float value
# Cannot set gray non-stroke color because /'P358' is an invalid float value
# Cannot set gray non-stroke color because /'P359' is an invalid float value
# Cannot set gray non-stroke color because /'P360' is an invalid float value
# Cannot set gray non-stroke color because /'P361' is an invalid float value
# Cannot set gray non-stroke color because /'P362' is an invalid float value
# Cannot set gray non-stroke color because /'P363' is an invalid float value
# Cannot set gray non-stroke color because /'P364' is an invalid float value
# Cannot set gray non-stroke color because /'P365' is an invalid float value
# Cannot set gray non-stroke color because /'P366' is an invalid float value
# Cannot set gray non-stroke color because /'P367' is an invalid float value
# Cannot set gray non-stroke color because /'P368' is an invalid float value
# Cannot set gray non-stroke color because /'P369' is an invalid float value
# Cannot set gray non-stroke color because /'P370' is an invalid float value
# Cannot set gray non-stroke color because /'P371' is an invalid float value
# Cannot set gray non-stroke color because /'P372' is an invalid float value
# Cannot set gray non-stroke color because /'P373' is an invalid float value
# Cannot set gray non-stroke color because /'P374' is an invalid float value
# Cannot set gray non-stroke color because /'P375' is an invalid float value
# Cannot set gray non-stroke color because /'P376' is an invalid float value
# Cannot set gray non-stroke color because /'P377' is an invalid float value
# Cannot set gray non-stroke color because /'P378' is an invalid float value
# Cannot set gray non-stroke color because /'P379' is an invalid float value
# Cannot set gray non-stroke color because /'P380' is an invalid float value
# Cannot set gray non-stroke color because /'P381' is an invalid float value
# Cannot set gray non-stroke color because /'P382' is an invalid float value
# Cannot set gray non-stroke color because /'P383' is an invalid float value
# Cannot set gray non-stroke color because /'P384' is an invalid float value
# Cannot set gray non-stroke color because /'P385' is an invalid float value
# Cannot set gray non-stroke color because /'P386' is an invalid float value
# Cannot set gray non-stroke color because /'P387' is an invalid float value
# Cannot set gray non-stroke color because /'P388' is an invalid float value
# Cannot set gray non-stroke color because /'P389' is an invalid float value
# Cannot set gray non-stroke color because /'P390' is an invalid float value
# Cannot set gray non-stroke color because /'P391' is an invalid float value
# Cannot set gray non-stroke color because /'P392' is an invalid float value
# Cannot set gray non-stroke color because /'P393' is an invalid float value
# Cannot set gray non-stroke color because /'P394' is an invalid float value
# Cannot set gray non-stroke color because /'P395' is an invalid float value
# Cannot set gray non-stroke color because /'P396' is an invalid float value
# Cannot set gray non-stroke color because /'P397' is an invalid float value
# Cannot set gray non-stroke color because /'P398' is an invalid float value
# Cannot set gray non-stroke color because /'P399' is an invalid float value
# Cannot set gray non-stroke color because /'P400' is an invalid float value
# Cannot set gray non-stroke color because /'P401' is an invalid float value
# Cannot set gray non-stroke color because /'P402' is an invalid float value
# Cannot set gray non-stroke color because /'P403' is an invalid float value
# Cannot set gray non-stroke color because /'P404' is an invalid float value
# Cannot set gray non-stroke color because /'P405' is an invalid float value
# Cannot set gray non-stroke color because /'P406' is an invalid float value
# Cannot set gray non-stroke color because /'P407' is an invalid float value
# Cannot set gray non-stroke color because /'P408' is an invalid float value
# Cannot set gray non-stroke color because /'P409' is an invalid float value
# Cannot set gray non-stroke color because /'P410' is an invalid float value
# Cannot set gray non-stroke color because /'P411' is an invalid float value
# Cannot set gray non-stroke color because /'P412' is an invalid float value
# Cannot set gray non-stroke color because /'P413' is an invalid float value
# Cannot set gray non-stroke color because /'P414' is an invalid float value
# Cannot set gray non-stroke color because /'P415' is an invalid float value
# Cannot set gray non-stroke color because /'P416' is an invalid float value
# Cannot set gray non-stroke color because /'P417' is an invalid float value
# Cannot set gray non-stroke color because /'P418' is an invalid float value
# Cannot set gray non-stroke color because /'P419' is an invalid float value
# Cannot set gray non-stroke color because /'P420' is an invalid float value
# Cannot set gray non-stroke color because /'P421' is an invalid float value
# Cannot set gray non-stroke color because /'P422' is an invalid float value
# Cannot set gray non-stroke color because /'P423' is an invalid float value
# Cannot set gray non-stroke color because /'P424' is an invalid float value
# Cannot set gray non-stroke color because /'P425' is an invalid float value
# Cannot set gray non-stroke color because /'P426' is an invalid float value
# Cannot set gray non-stroke color because /'P427' is an invalid float value
# Cannot set gray non-stroke color because /'P428' is an invalid float value
# Cannot set gray non-stroke color because /'P429' is an invalid float value
# Cannot set gray non-stroke color because /'P430' is an invalid float value
# Cannot set gray non-stroke color because /'P431' is an invalid float value
# Cannot set gray non-stroke color because /'P432' is an invalid float value
# Cannot set gray non-stroke color because /'P433' is an invalid float value
# Cannot set gray non-stroke color because /'P434' is an invalid float value
# Cannot set gray non-stroke color because /'P435' is an invalid float value
# Cannot set gray non-stroke color because /'P436' is an invalid float value
# Cannot set gray non-stroke color because /'P437' is an invalid float value
# Cannot set gray non-stroke color because /'P438' is an invalid float value
# Cannot set gray non-stroke color because /'P439' is an invalid float value
# Cannot set gray non-stroke color because /'P440' is an invalid float value
# Cannot set gray non-stroke color because /'P441' is an invalid float value
# Cannot set gray non-stroke color because /'P442' is an invalid float value
# Cannot set gray non-stroke color because /'P443' is an invalid float value
# Cannot set gray non-stroke color because /'P444' is an invalid float value
# Cannot set gray non-stroke color because /'P445' is an invalid float value
# Cannot set gray non-stroke color because /'P446' is an invalid float value
# Cannot set gray non-stroke color because /'P447' is an invalid float value
# Cannot set gray non-stroke color because /'P448' is an invalid float value
# Cannot set gray non-stroke color because /'P449' is an invalid float value
# Cannot set gray non-stroke color because /'P450' is an invalid float value
# Cannot set gray non-stroke color because /'P451' is an invalid float value
# Cannot set gray non-stroke color because /'P452' is an invalid float value
# Cannot set gray non-stroke color because /'P453' is an invalid float value
# Cannot set gray non-stroke color because /'P454' is an invalid float value
# Cannot set gray non-stroke color because /'P455' is an invalid float value
# Cannot set gray non-stroke color because /'P456' is an invalid float value
# Cannot set gray non-stroke color because /'P457' is an invalid float value
# Cannot set gray non-stroke color because /'P458' is an invalid float value
# Cannot set gray non-stroke color because /'P459' is an invalid float value
# Cannot set gray non-stroke color because /'P460' is an invalid float value
# Cannot set gray non-stroke color because /'P461' is an invalid float value
# Cannot set gray non-stroke color because /'P462' is an invalid float value
# Cannot set gray non-stroke color because /'P463' is an invalid float value
# Cannot set gray non-stroke color because /'P464' is an invalid float value
# Cannot set gray non-stroke color because /'P465' is an invalid float value
# Cannot set gray non-stroke color because /'P466' is an invalid float value
# Cannot set gray non-stroke color because /'P467' is an invalid float value
# Cannot set gray non-stroke color because /'P468' is an invalid float value
# Cannot set gray non-stroke color because /'P469' is an invalid float value
# Cannot set gray non-stroke color because /'P470' is an invalid float value
# Cannot set gray non-stroke color because /'P471' is an invalid float value
# Cannot set gray non-stroke color because /'P472' is an invalid float value
# Cannot set gray non-stroke color because /'P473' is an invalid float value
# Cannot set gray non-stroke color because /'P474' is an invalid float value
# Cannot set gray non-stroke color because /'P475' is an invalid float value
# Cannot set gray non-stroke color because /'P476' is an invalid float value
# Cannot set gray non-stroke color because /'P477' is an invalid float value
# Cannot set gray non-stroke color because /'P478' is an invalid float value
# Cannot set gray non-stroke color because /'P479' is an invalid float value
# Cannot set gray non-stroke color because /'P480' is an invalid float value
# Cannot set gray non-stroke color because /'P481' is an invalid float value
# Cannot set gray non-stroke color because /'P482' is an invalid float value
# Cannot set gray non-stroke color because /'P483' is an invalid float value
# Cannot set gray non-stroke color because /'P484' is an invalid float value
# Cannot set gray non-stroke color because /'P485' is an invalid float value
# Cannot set gray non-stroke color because /'P486' is an invalid float value
# Cannot set gray non-stroke color because /'P487' is an invalid float value
# Cannot set gray non-stroke color because /'P488' is an invalid float value
# Cannot set gray non-stroke color because /'P489' is an invalid float value
# Cannot set gray non-stroke color because /'P490' is an invalid float value
# Cannot set gray non-stroke color because /'P491' is an invalid float value
# Cannot set gray non-stroke color because /'P492' is an invalid float value
# Cannot set gray non-stroke color because /'P493' is an invalid float value
# Cannot set gray non-stroke color because /'P494' is an invalid float value
# Cannot set gray non-stroke color because /'P495' is an invalid float value
# Cannot set gray non-stroke color because /'P496' is an invalid float value
# Cannot set gray non-stroke color because /'P497' is an invalid float value
# Cannot set gray non-stroke color because /'P498' is an invalid float value
# Cannot set gray non-stroke color because /'P499' is an invalid float value
# Cannot set gray non-stroke color because /'P500' is an invalid float value
# Cannot set gray non-stroke color because /'P501' is an invalid float value
# Cannot set gray non-stroke color because /'P502' is an invalid float value
# Cannot set gray non-stroke color because /'P503' is an invalid float value
# Cannot set gray non-stroke color because /'P504' is an invalid float value
# Cannot set gray non-stroke color because /'P505' is an invalid float value
# Cannot set gray non-stroke color because /'P506' is an invalid float value
# Cannot set gray non-stroke color because /'P507' is an invalid float value
# Cannot set gray non-stroke color because /'P508' is an invalid float value
# Cannot set gray non-stroke color because /'P509' is an invalid float value
# Cannot set gray non-stroke color because /'P510' is an invalid float value
# Cannot set gray non-stroke color because /'P511' is an invalid float value
# Cannot set gray non-stroke color because /'P512' is an invalid float value
# Cannot set gray non-stroke color because /'P513' is an invalid float value
# Cannot set gray non-stroke color because /'P514' is an invalid float value
# Cannot set gray non-stroke color because /'P515' is an invalid float value
# Cannot set gray non-stroke color because /'P516' is an invalid float value
# Cannot set gray non-stroke color because /'P517' is an invalid float value
# Cannot set gray non-stroke color because /'P518' is an invalid float value
# Cannot set gray non-stroke color because /'P519' is an invalid float value
# Cannot set gray non-stroke color because /'P520' is an invalid float value
# Cannot set gray non-stroke color because /'P521' is an invalid float value
# Cannot set gray non-stroke color because /'P522' is an invalid float value
# Cannot set gray non-stroke color because /'P523' is an invalid float value
# Cannot set gray non-stroke color because /'P524' is an invalid float value
# Cannot set gray non-stroke color because /'P525' is an invalid float value
# Cannot set gray non-stroke color because /'P526' is an invalid float value
# Cannot set gray non-stroke color because /'P527' is an invalid float value
# Cannot set gray non-stroke color because /'P528' is an invalid float value
# Cannot set gray non-stroke color because /'P529' is an invalid float value
# Cannot set gray non-stroke color because /'P530' is an invalid float value
# Cannot set gray non-stroke color because /'P531' is an invalid float value
# Cannot set gray non-stroke color because /'P532' is an invalid float value
# Cannot set gray non-stroke color because /'P533' is an invalid float value
# Cannot set gray non-stroke color because /'P534' is an invalid float value
# Cannot set gray non-stroke color because /'P535' is an invalid float value
# Cannot set gray non-stroke color because /'P536' is an invalid float value
# Cannot set gray non-stroke color because /'P537' is an invalid float value
# Cannot set gray non-stroke color because /'P538' is an invalid float value
# Cannot set gray non-stroke color because /'P539' is an invalid float value
# Cannot set gray non-stroke color because /'P540' is an invalid float value
# Cannot set gray non-stroke color because /'P541' is an invalid float value
# Cannot set gray non-stroke color because /'P542' is an invalid float value
# Cannot set gray non-stroke color because /'P543' is an invalid float value
# Cannot set gray non-stroke color because /'P544' is an invalid float value
# Cannot set gray non-stroke color because /'P545' is an invalid float value
# Cannot set gray non-stroke color because /'P546' is an invalid float value
# Cannot set gray non-stroke color because /'P547' is an invalid float value
# Cannot set gray non-stroke color because /'P548' is an invalid float value
# Cannot set gray non-stroke color because /'P549' is an invalid float value
# Cannot set gray non-stroke color because /'P550' is an invalid float value
# Cannot set gray non-stroke color because /'P551' is an invalid float value
# Cannot set gray non-stroke color because /'P552' is an invalid float value
# Cannot set gray non-stroke color because /'P553' is an invalid float value
# Cannot set gray non-stroke color because /'P554' is an invalid float value
# Cannot set gray non-stroke color because /'P555' is an invalid float value
# Cannot set gray non-stroke color because /'P556' is an invalid float value
# Cannot set gray non-stroke color because /'P557' is an invalid float value
# Cannot set gray non-stroke color because /'P558' is an invalid float value
# Cannot set gray non-stroke color because /'P559' is an invalid float value
# Cannot set gray non-stroke color because /'P560' is an invalid float value
# Cannot set gray non-stroke color because /'P561' is an invalid float value
# Cannot set gray non-stroke color because /'P562' is an invalid float value
# Cannot set gray non-stroke color because /'P563' is an invalid float value
# Cannot set gray non-stroke color because /'P564' is an invalid float value
# Cannot set gray non-stroke color because /'P565' is an invalid float value
# Cannot set gray non-stroke color because /'P566' is an invalid float value
# Cannot set gray non-stroke color because /'P567' is an invalid float value
# Cannot set gray non-stroke color because /'P568' is an invalid float value
# Cannot set gray non-stroke color because /'P569' is an invalid float value
# Cannot set gray non-stroke color because /'P570' is an invalid float value
# Cannot set gray non-stroke color because /'P571' is an invalid float value
# Cannot set gray non-stroke color because /'P572' is an invalid float value
# Cannot set gray non-stroke color because /'P573' is an invalid float value
# Cannot set gray non-stroke color because /'P574' is an invalid float value
# Cannot set gray non-stroke color because /'P575' is an invalid float value
# Cannot set gray non-stroke color because /'P576' is an invalid float value
# Cannot set gray non-stroke color because /'P577' is an invalid float value
# Cannot set gray non-stroke color because /'P578' is an invalid float value
# Cannot set gray non-stroke color because /'P579' is an invalid float value
# Cannot set gray non-stroke color because /'P580' is an invalid float value
# Cannot set gray non-stroke color because /'P581' is an invalid float value
# Cannot set gray non-stroke color because /'P582' is an invalid float value
# Cannot set gray non-stroke color because /'P583' is an invalid float value
# Cannot set gray non-stroke color because /'P584' is an invalid float value
# Cannot set gray non-stroke color because /'P585' is an invalid float value
# Cannot set gray non-stroke color because /'P586' is an invalid float value
# Cannot set gray non-stroke color because /'P587' is an invalid float value
# Cannot set gray non-stroke color because /'P588' is an invalid float value
# Cannot set gray non-stroke color because /'P589' is an invalid float value
# Cannot set gray non-stroke color because /'P590' is an invalid float value
# Cannot set gray non-stroke color because /'P591' is an invalid float value
# Cannot set gray non-stroke color because /'P592' is an invalid float value
# Cannot set gray non-stroke color because /'P593' is an invalid float value
# Cannot set gray non-stroke color because /'P594' is an invalid float value
# Cannot set gray non-stroke color because /'P595' is an invalid float value
# Cannot set gray non-stroke color because /'P596' is an invalid float value
# Cannot set gray non-stroke color because /'P597' is an invalid float value
# Cannot set gray non-stroke color because /'P598' is an invalid float value
# Cannot set gray non-stroke color because /'P599' is an invalid float value
# Cannot set gray non-stroke color because /'P600' is an invalid float value
# Cannot set gray non-stroke color because /'P601' is an invalid float value
# Cannot set gray non-stroke color because /'P602' is an invalid float value
# Cannot set gray non-stroke color because /'P603' is an invalid float value
# Cannot set gray non-stroke color because /'P604' is an invalid float value
# Cannot set gray non-stroke color because /'P605' is an invalid float value
# Cannot set gray non-stroke color because /'P606' is an invalid float value
# Cannot set gray non-stroke color because /'P607' is an invalid float value
# Cannot set gray non-stroke color because /'P608' is an invalid float value
# Cannot set gray non-stroke color because /'P609' is an invalid float value
# Cannot set gray non-stroke color because /'P610' is an invalid float value
# Cannot set gray non-stroke color because /'P611' is an invalid float value
# Cannot set gray non-stroke color because /'P612' is an invalid float value
# Cannot set gray non-stroke color because /'P613' is an invalid float value
# Cannot set gray non-stroke color because /'P614' is an invalid float value
# Cannot set gray non-stroke color because /'P615' is an invalid float value
# Cannot set gray non-stroke color because /'P616' is an invalid float value
# Cannot set gray non-stroke color because /'P617' is an invalid float value
# Cannot set gray non-stroke color because /'P618' is an invalid float value
# Cannot set gray non-stroke color because /'P619' is an invalid float value
# Cannot set gray non-stroke color because /'P620' is an invalid float value
# Cannot set gray non-stroke color because /'P621' is an invalid float value
# Cannot set gray non-stroke color because /'P622' is an invalid float value
# Cannot set gray non-stroke color because /'P623' is an invalid float value
# Cannot set gray non-stroke color because /'P624' is an invalid float value
# Cannot set gray non-stroke color because /'P625' is an invalid float value
# Cannot set gray non-stroke color because /'P626' is an invalid float value
# Cannot set gray non-stroke color because /'P627' is an invalid float value
# Cannot set gray non-stroke color because /'P628' is an invalid float value
# Cannot set gray non-stroke color because /'P629' is an invalid float value
# Cannot set gray non-stroke color because /'P630' is an invalid float value
# Cannot set gray non-stroke color because /'P631' is an invalid float value
# Cannot set gray non-stroke color because /'P632' is an invalid float value
# Cannot set gray non-stroke color because /'P633' is an invalid float value
# Cannot set gray non-stroke color because /'P634' is an invalid float value
# Cannot set gray non-stroke color because /'P635' is an invalid float value
# Cannot set gray non-stroke color because /'P636' is an invalid float value
# Cannot set gray non-stroke color because /'P637' is an invalid float value
# Cannot set gray non-stroke color because /'P638' is an invalid float value
# Cannot set gray non-stroke color because /'P639' is an invalid float value
# Cannot set gray non-stroke color because /'P640' is an invalid float value
# Cannot set gray non-stroke color because /'P641' is an invalid float value
# Cannot set gray non-stroke color because /'P642' is an invalid float value
# Cannot set gray non-stroke color because /'P643' is an invalid float value
# Cannot set gray non-stroke color because /'P644' is an invalid float value
# Cannot set gray non-stroke color because /'P645' is an invalid float value
# Cannot set gray non-stroke color because /'P646' is an invalid float value
# Cannot set gray non-stroke color because /'P647' is an invalid float value
# Cannot set gray non-stroke color because /'P648' is an invalid float value
# ...
# Cannot set gray non-stroke color because /'P1277' is an invalid float value
# Cannot set gray non-stroke color because /'P1278' is an invalid float value
# Cannot set gray non-stroke color because /'P1279' is an invalid float value
# Cannot set gray non-stroke color because /'P1280' is an invalid float value
# Cannot set gray non-stroke color because /'P1281' is an invalid float value
# Cannot set gray non-stroke color because /'P1282' is an invalid float value
# Cannot set gray non-stroke color because /'P1283' is an invalid float value
# Cannot set gray non-stroke color because /'P1284' is an invalid float value
# Cannot set gray non-stroke color because /'P1285' is an invalid float value
# Cannot set gray non-stroke color because /'P1286' is an invalid float value
# Cannot set gray non-stroke color because /'P1287' is an invalid float value
# Cannot set gray non-stroke color because /'P1288' is an invalid float value
# Cannot set gray non-stroke color because /'P1289' is an invalid float value
# Cannot set gray non-stroke color because /'P1290' is an invalid float value
# Cannot set gray non-stroke color because /'P1291' is an invalid float value
# Cannot set gray non-stroke color because /'P1292' is an invalid float value
# Cannot set gray non-stroke color because /'P1293' is an invalid float value
# Cannot set gray non-stroke color because /'P1294' is an invalid float value
# Cannot set gray non-stroke color because /'P1295' is an invalid float value
# Cannot set gray non-stroke color because /'P1296' is an invalid float value
# Cannot set gray non-stroke color because /'P1297' is an invalid float value
# Cannot set gray non-stroke color because /'P1298' is an invalid float value
# Cannot set gray non-stroke color because /'P1299' is an invalid float value
# Cannot set gray non-stroke color because /'P1300' is an invalid float value
# Cannot set gray non-stroke color because /'P1301' is an invalid float value
# Cannot set gray non-stroke color because /'P1302' is an invalid float value
# Cannot set gray non-stroke color because /'P1303' is an invalid float value
# Cannot set gray non-stroke color because /'P1304' is an invalid float value
# Cannot set gray non-stroke color because /'P1305' is an invalid float value
# Cannot set gray non-stroke color because /'P1306' is an invalid float value
# Cannot set gray non-stroke color because /'P1307' is an invalid float value
# Cannot set gray non-stroke color because /'P1308' is an invalid float value
# Cannot set gray non-stroke color because /'P1309' is an invalid float value
# Cannot set gray non-stroke color because /'P1310' is an invalid float value
# Cannot set gray non-stroke color because /'P1311' is an invalid float value
# Cannot set gray non-stroke color because /'P1312' is an invalid float value
# Cannot set gray non-stroke color because /'P1313' is an invalid float value
# Cannot set gray non-stroke color because /'P1314' is an invalid float value
# Cannot set gray non-stroke color because /'P1315' is an invalid float value
# Cannot set gray non-stroke color because /'P1316' is an invalid float value
# Cannot set gray non-stroke color because /'P1317' is an invalid float value
# Cannot set gray non-stroke color because /'P1318' is an invalid float value
# Cannot set gray non-stroke color because /'P1319' is an invalid float value
# Cannot set gray non-stroke color because /'P1320' is an invalid float value
# Cannot set gray non-stroke color because /'P1321' is an invalid float value
# Cannot set gray non-stroke color because /'P1322' is an invalid float value
# Cannot set gray non-stroke color because /'P1323' is an invalid float value
# Cannot set gray non-stroke color because /'P1324' is an invalid float value
# Cannot set gray non-stroke color because /'P1325' is an invalid float value
# Cannot set gray non-stroke color because /'P1326' is an invalid float value
# Cannot set gray non-stroke color because /'P1327' is an invalid float value
# Cannot set gray non-stroke color because /'P1328' is an invalid float value
# Cannot set gray non-stroke color because /'P1329' is an invalid float value
# Cannot set gray non-stroke color because /'P1330' is an invalid float value
# Cannot set gray non-stroke color because /'P1331' is an invalid float value
# Cannot set gray non-stroke color because /'P1332' is an invalid float value
# Cannot set gray non-stroke color because /'P1333' is an invalid float value
# Cannot set gray non-stroke color because /'P1334' is an invalid float value
# Cannot set gray non-stroke color because /'P1335' is an invalid float value
# Cannot set gray non-stroke color because /'P1336' is an invalid float value
# Cannot set gray non-stroke color because /'P1337' is an invalid float value
# Cannot set gray non-stroke color because /'P1338' is an invalid float value
# Cannot set gray non-stroke color because /'P1339' is an invalid float value
# Cannot set gray non-stroke color because /'P1340' is an invalid float value
# Cannot set gray non-stroke color because /'P1341' is an invalid float value
# Cannot set gray non-stroke color because /'P1342' is an invalid float value
# Cannot set gray non-stroke color because /'P1343' is an invalid float value
# Cannot set gray non-stroke color because /'P1344' is an invalid float value
# Cannot set gray non-stroke color because /'P1345' is an invalid float value
# Cannot set gray non-stroke color because /'P1346' is an invalid float value
# Cannot set gray non-stroke color because /'P1347' is an invalid float value
# Cannot set gray non-stroke color because /'P1348' is an invalid float value
# Cannot set gray non-stroke color because /'P1349' is an invalid float value
# Cannot set gray non-stroke color because /'P1350' is an invalid float value
# Cannot set gray non-stroke color because /'P1351' is an invalid float value
# Cannot set gray non-stroke color because /'P1352' is an invalid float value
# Cannot set gray non-stroke color because /'P1353' is an invalid float value
# Cannot set gray non-stroke color because /'P1354' is an invalid float value
# Cannot set gray non-stroke color because /'P1355' is an invalid float value
# Cannot set gray non-stroke color because /'P1356' is an invalid float value
# Cannot set gray non-stroke color because /'P1357' is an invalid float value
# Cannot set gray non-stroke color because /'P1358' is an invalid float value
# Cannot set gray non-stroke color because /'P1359' is an invalid float value
# Cannot set gray non-stroke color because /'P1360' is an invalid float value
# Cannot set gray non-stroke color because /'P1361' is an invalid float value
# Cannot set gray non-stroke color because /'P1362' is an invalid float value
# Cannot set gray non-stroke color because /'P1363' is an invalid float value
# Cannot set gray non-stroke color because /'P1364' is an invalid float value
# Cannot set gray non-stroke color because /'P1365' is an invalid float value
# Cannot set gray non-stroke color because /'P1366' is an invalid float value
# Cannot set gray non-stroke color because /'P1367' is an invalid float value
# Cannot set gray non-stroke color because /'P1368' is an invalid float value
# Cannot set gray non-stroke color because /'P1369' is an invalid float value
# Cannot set gray non-stroke color because /'P1371' is an invalid float value
# Cannot set gray non-stroke color because /'P1372' is an invalid float value
# Cannot set gray non-stroke color because /'P1373' is an invalid float value
# Cannot set gray non-stroke color because /'P1374' is an invalid float value
# Cannot set gray non-stroke color because /'P1375' is an invalid float value
# Cannot set gray non-stroke color because /'P1376' is an invalid float value
# Cannot set gray non-stroke color because /'P1377' is an invalid float value
# Cannot set gray non-stroke color because /'P1378' is an invalid float value
# Cannot set gray non-stroke color because /'P1379' is an invalid float value
# Cannot set gray non-stroke color because /'P1380' is an invalid float value
# Cannot set gray non-stroke color because /'P1381' is an invalid float value
# Cannot set gray non-stroke color because /'P1382' is an invalid float value
# Cannot set gray non-stroke color because /'P1383' is an invalid float value
# Cannot set gray non-stroke color because /'P1384' is an invalid float value
# Cannot set gray non-stroke color because /'P1385' is an invalid float value
# Cannot set gray non-stroke color because /'P1386' is an invalid float value
# Cannot set gray non-stroke color because /'P1387' is an invalid float value
# Cannot set gray non-stroke color because /'P1388' is an invalid float value
# Cannot set gray non-stroke color because /'P1389' is an invalid float value
# Cannot set gray non-stroke color because /'P1390' is an invalid float value
# Cannot set gray non-stroke color because /'P1391' is an invalid float value
# Cannot set gray non-stroke color because /'P1392' is an invalid float value
# Cannot set gray non-stroke color because /'P1393' is an invalid float value
# Cannot set gray non-stroke color because /'P1394' is an invalid float value
# Cannot set gray non-stroke color because /'P1395' is an invalid float value
# Cannot set gray non-stroke color because /'P1396' is an invalid float value
# Cannot set gray non-stroke color because /'P1397' is an invalid float value
# Cannot set gray non-stroke color because /'P1398' is an invalid float value
# Cannot set gray non-stroke color because /'P1399' is an invalid float value
# Cannot set gray non-stroke color because /'P1400' is an invalid float value
# Cannot set gray non-stroke color because /'P1401' is an invalid float value
# Cannot set gray non-stroke color because /'P1402' is an invalid float value
# Cannot set gray non-stroke color because /'P1403' is an invalid float value
# Cannot set gray non-stroke color because /'P1404' is an invalid float value
# Cannot set gray non-stroke color because /'P1405' is an invalid float value
# Cannot set gray non-stroke color because /'P1406' is an invalid float value
# Cannot set gray non-stroke color because /'P1407' is an invalid float value
# Cannot set gray non-stroke color because /'P1408' is an invalid float value
# Cannot set gray non-stroke color because /'P1409' is an invalid float value
# Cannot set gray non-stroke color because /'P1410' is an invalid float value
# Cannot set gray non-stroke color because /'P1411' is an invalid float value
# Cannot set gray non-stroke color because /'P1412' is an invalid float value
# Cannot set gray non-stroke color because /'P1413' is an invalid float value
# Cannot set gray non-stroke color because /'P1414' is an invalid float value
# Cannot set gray non-stroke color because /'P1415' is an invalid float value
# Cannot set gray non-stroke color because /'P1416' is an invalid float value
# Cannot set gray non-stroke color because /'P1417' is an invalid float value
# Cannot set gray non-stroke color because /'P1418' is an invalid float value
# Cannot set gray non-stroke color because /'P1419' is an invalid float value
# Cannot set gray non-stroke color because /'P1420' is an invalid float value
# Cannot set gray non-stroke color because /'P1421' is an invalid float value
# Cannot set gray non-stroke color because /'P1422' is an invalid float value
# Cannot set gray non-stroke color because /'P1423' is an invalid float value
# Cannot set gray non-stroke color because /'P1424' is an invalid float value
# Cannot set gray non-stroke color because /'P1425' is an invalid float value
# Cannot set gray non-stroke color because /'P1426' is an invalid float value
# Cannot set gray non-stroke color because /'P1427' is an invalid float value
# Cannot set gray non-stroke color because /'P1428' is an invalid float value
# Cannot set gray non-stroke color because /'P1429' is an invalid float value
# Cannot set gray non-stroke color because /'P1430' is an invalid float value
# Cannot set gray non-stroke color because /'P1431' is an invalid float value
# Cannot set gray non-stroke color because /'P1432' is an invalid float value
# Cannot set gray non-stroke color because /'P1433' is an invalid float value
# Cannot set gray non-stroke color because /'P1434' is an invalid float value
# Cannot set gray non-stroke color because /'P1435' is an invalid float value
# Cannot set gray non-stroke color because /'P1436' is an invalid float value
# Cannot set gray non-stroke color because /'P1437' is an invalid float value
# Cannot set gray non-stroke color because /'P1438' is an invalid float value
# Cannot set gray non-stroke color because /'P1439' is an invalid float value
# Cannot set gray non-stroke color because /'P1440' is an invalid float value
# Cannot set gray non-stroke color because /'P1441' is an invalid float value
# Cannot set gray non-stroke color because /'P1442' is an invalid float value
# Cannot set gray non-stroke color because /'P1443' is an invalid float value
# Cannot set gray non-stroke color because /'P1444' is an invalid float value
# Cannot set gray non-stroke color because /'P1445' is an invalid float value
# Cannot set gray non-stroke color because /'P1446' is an invalid float value
# Cannot set gray non-stroke color because /'P1447' is an invalid float value
# Cannot set gray non-stroke color because /'P1448' is an invalid float value
# Cannot set gray non-stroke color because /'P1449' is an invalid float value
# Cannot set gray non-stroke color because /'P1450' is an invalid float value
# Cannot set gray non-stroke color because /'P1451' is an invalid float value
# Cannot set gray non-stroke color because /'P1452' is an invalid float value
# Cannot set gray non-stroke color because /'P1453' is an invalid float value
# Cannot set gray non-stroke color because /'P1454' is an invalid float value
# Cannot set gray non-stroke color because /'P1455' is an invalid float value
# Cannot set gray non-stroke color because /'P1456' is an invalid float value
# Cannot set gray non-stroke color because /'P1457' is an invalid float value
# Cannot set gray non-stroke color because /'P1458' is an invalid float value
# Cannot set gray non-stroke color because /'P1459' is an invalid float value
# Cannot set gray non-stroke color because /'P1460' is an invalid float value
# Cannot set gray non-stroke color because /'P1461' is an invalid float value
# Cannot set gray non-stroke color because /'P1462' is an invalid float value
# Cannot set gray non-stroke color because /'P1463' is an invalid float value
# Cannot set gray non-stroke color because /'P1464' is an invalid float value
# Cannot set gray non-stroke color because /'P1465' is an invalid float value
# Cannot set gray non-stroke color because /'P1466' is an invalid float value
# Cannot set gray non-stroke color because /'P1467' is an invalid float value
# Cannot set gray non-stroke color because /'P1468' is an invalid float value
# Cannot set gray non-stroke color because /'P1469' is an invalid float value
# Cannot set gray non-stroke color because /'P1470' is an invalid float value
# Cannot set gray non-stroke color because /'P1471' is an invalid float value
# Cannot set gray non-stroke color because /'P1472' is an invalid float value
# Cannot set gray non-stroke color because /'P1473' is an invalid float value
# Cannot set gray non-stroke color because /'P1474' is an invalid float value
# Cannot set gray non-stroke color because /'P1475' is an invalid float value
# Cannot set gray non-stroke color because /'P1476' is an invalid float value
# Cannot set gray non-stroke color because /'P1477' is an invalid float value
# Cannot set gray non-stroke color because /'P1478' is an invalid float value
# Cannot set gray non-stroke color because /'P1479' is an invalid float value
# Cannot set gray non-stroke color because /'P1480' is an invalid float value
# Cannot set gray non-stroke color because /'P1481' is an invalid float value
# Cannot set gray non-stroke color because /'P1482' is an invalid float value
# Cannot set gray non-stroke color because /'P1483' is an invalid float value
# Cannot set gray non-stroke color because /'P1484' is an invalid float value
# Cannot set gray non-stroke color because /'P1485' is an invalid float value
# Cannot set gray non-stroke color because /'P1486' is an invalid float value
# ❌ Failed to extract data from: Q1 2024.pdf
# 📄 Processing: Q1 2025.pdf

# %%
# --- 4. DATAFRAME CREATION AND SAVING ---
if records:
    df = pd.DataFrame(records)
    column_order = [
        'provider', 'year', 'quarter', 
        'health', 'personal_accident', 'travel', 'total', 'source_file'
    ]
    df = df[column_order]

    out_csv = os.path.join(OUT_DIR, "premium_summary_universal.csv")
    df.to_csv(out_csv, index=False)
    
    print(f"\n✅ Data successfully saved to CSV: {out_csv}")
    print("\n--- DataFrame Preview ---")
    display(df) # 'display(df)' gives a nice formatted table in notebooks
else:
    print("\nNo data was extracted, so no file was saved.")
